# %%
import pandas as pd
import numpy as numpy
df = pd.read_csv("data_wrangling_medical_2021_u6773547.csv")

# %%
df
# Out:
#           rec_id         ssn first_name middle_name   last_name gender  \
# 0      rec-38255  a119167529     joseph     jackson   rothstein      m
# 1      rec-96960  h148559060      james           m     hinnant      f
# 2      rec-89846  i182575302    michael        juan   whitfield      f
# 3      rec-85752  e141244372      bryan    lawrence        roos      f
# 4      rec-60433  e156698479       jack        dale     mullins      m
# ...          ...         ...        ...         ...         ...    ...
# 19995  rec-65265  f140131186   reginald      thomas  ballentine      m
# 19996  rec-53589  g150433327   victoria       diane     goodman      f
# 19997  rec-64261  f193935403      mayra           j       ligon      f
# 19998   rec-2147  a174082079      kisha     michael     depaulo      m
# 19999  rec-57825  b130302016    shritha       marie    mckinney      f
#
#        age_at_consultation  birth_date  new_medi      medicare_number  ...  \
# ...
